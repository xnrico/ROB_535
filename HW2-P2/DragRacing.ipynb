# %% [markdown]
# # Drag Racing
#
# In this task, you will design a nonlinear MPC controller to let the car to travel as far as possible in positive $x$ direction in a fixed time interval.
#
# You are supposed to keep close to $y = 0$, while avoiding the obstacle located at $x = 500, y = 0$.
#
# We consider the car model with tire dynamics introduced in the lecture.
#
# The key to this problem is to use as much tire forces as possible, while ensuring that the car does not lose control.

# %% [markdown]
# # Car Dynamics
#
# <div>
# <img src="CarModel.png" width="1200">
# </div>
#
# We consider the car dynamics with lumped rear and front tire forces.
#
# For simplification, we consider the positions and orientation in the world coordinates.
#
# \begin{aligned}
# \dot{U}_x & =\frac{F_{x_f} \cos \delta-F_{y_f} \sin \delta+F_{x_r}-F_d}{m}+r U_y \\
# \dot{U}_y & =\frac{F_{y_f} \cos \delta+F_{x_f} \sin \delta+F_{y_r}+F_b}{m}-r U_x \\
# \dot{r} & =\frac{a\left(F_{y_f} \cos \delta+F_{x_f} \sin \delta\right)-b F_{y_r}}{I_{z z}} \\
# \dot{x} & = \cos(\phi)U_x - \sin(\phi)U_y  \\
# \dot{y} & = \sin(\phi)U_x + \sin(\phi)U_y   \\
# \dot{\phi} & =r  . \\
# \end{aligned}
#
#
# We consider the Euler first order integration to discretize the model.
#
# The actual control input of the vehicle is the traction force $F_w$ and steering angle $\delta$, which implicitly appears in the vehicle dynamics via the tire force $F_{x_f}$, $F_{y_f}$, $F_{x_r}$ and $F_{y_r}$.
#
# For more details of the **traction force model** and **tire force model**, please refer to the notebook of **Example - 4** and the **car simulator**.

# %% [markdown]
# ## Model parameter
#
# The meaning of the model parameters are provided in the following charts. Please refer to the **Param** variable in **utils.py** for the actual values.
#
# <div>
# <img src="Param.png" width="600">
# </div>
#
#
# Laurense, V.A. and Gerdes, J.C., 2021. Long-horizon vehicle motion planning and control through serially cascaded model complexity. IEEE Transactions on Control Systems Technology, 30(1), pp.166-179.

# %% [markdown]
# ## Modified tire model for control and optimization
#
# The brush tire model saturated when the slip angle is greater than the threshold. Such saturated region will result in zero gradient, which is harmful for optimization.
#
# To solve the problem, we introduce the modified tire model for control, such that the tire forces will not saturated.
#
# We consider the modified maximal lateral tire force:
# $$
# \tilde{F}^{\max}_{y} = \sqrt{(\mu F_z)^2 - (0.99\tilde{F}_x)^2 }
# $$
# We here add an additional coefficient $0.99$ to avoid exceeding the firction limits.
#
# Then we introduce an variable $\xi$ and define the modified slide sliping angle:
#
# $$
# \alpha^{mod} = \arctan{\left( \frac{3F_y^{\max}\xi }{C_{\alpha}} \right)}.
# $$
#
# Finally, we have the modified brush tire model for control:
#
# \begin{aligned}
# \tilde{F}_y&=\left\{\begin{array}{l}
# -C_\alpha \tan \alpha
# +\frac{C_\alpha^2}{3 \tilde{F}_y^{\max }}|\tan \alpha| \tan \alpha
# -\frac{C_\alpha^3}{27\left(\tilde{F}_y^{\max }\right)^2} \tan ^3 \alpha
# -C_\alpha\left(1-2 \xi+\xi^2\right) \tan \alpha \quad \text { if }|\alpha| \leq \alpha^{\bmod } \\
#
# -\tilde{F}_y^{\max }\left(3 \xi^2-2 \xi^3\right) \operatorname{sgn} \alpha \quad \text { otherwise }
# \end{array}\right. \\
# & =\tilde{f}_{\text {tire }}\left(\alpha, F_z, F_x\right) \text {. } \\
# &
# \end{aligned}
#
# We let $\xi$ be $0.85$ and provides the plot for comparison with the brush tire model. The dashed lines are the brush tire model without the modification.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import casadi as ca
import numpy as np
import numpy.matlib
import matplotlib.pyplot as plt
import time

import scipy.io

from utils import *
from sim import *
# from nmpc_dragracing_gsi import *
from nmpc_dragracing_student import *

# %%
Fx = 0.0
alpha = np.linspace(-0.4, 0.4, 100)

plt.figure(figsize=(10, 6))

Fy = tire_model_sim(alpha, 1000 * 9.81, 0, param["C_alpha_f"], param["mu_f"])
plt.plot(np.rad2deg(alpha), Fy / 1000, "r--", label = "$F_x = 0$")

Fy = tire_model_ctrl(alpha, 1000 * 9.81, 0, param["C_alpha_f"], param["mu_f"])
plt.plot(np.rad2deg(alpha), Fy / 1000, "r-",  label = "$F_x = 0$")

Fy = tire_model_sim(alpha, 1000 * 9.81, 6000, param["C_alpha_f"], param["mu_f"])
plt.plot(np.rad2deg(alpha), Fy / 1000, "b--", label = "$F_x = 6k$")

Fy = tire_model_ctrl(alpha, 1000 * 9.81, 6000, param["C_alpha_f"], param["mu_f"])
plt.plot(np.rad2deg(alpha), Fy / 1000, "b-",  label = "$F_x = 6k$")

Fy = tire_model_sim(alpha, 1000 * 9.81, 1000 * 9.81 * param["mu_f"], param["C_alpha_f"], param["mu_f"])
plt.plot(np.rad2deg(alpha), Fy / 1000, "g--", label = "$F_x = \mu F_z$")

Fy = tire_model_ctrl(alpha, 1000 * 9.81, 1000 * 9.81 * param["mu_f"], param["C_alpha_f"], param["mu_f"])
plt.plot(np.rad2deg(alpha), Fy / 1000, "g-", label = "$F_x = \mu F_z$")

plt.ylabel("$F_y$ (KN)")
plt.xlabel("alpha (deg)")
plt.legend()
plt.grid("on")

# %% [markdown]
# ## Nonlinear Model Predictive Control
#
# Let the state of the car be
#
# $$
# s_k:= \left[U_{x,k}, U_{y,k}, r_k, x_k, y_k, \phi_k \right], k = 0, 1, \dots, N.
# $$
#
# Let the control input of the car be
#
# $$
# u_k:= \left[ F_{x, k}, \delta_{k} \right], k = 0, 1, \dots, N-1.
# $$
#
# We introduce four auxiliary variable for each step:
#
# $$
# z_k:=\left[F_{y_f, k}, F_{y_r, k}, z_{\mu_f}, z_{\mu_r}\right], k = 0, 1, \dots, N-1.
# $$
#
# The first two variables will be used to enforce the tire force constraints, which means $F_{y_f, k}$ and $F_{y_r, k}$ will be explicit variables and related to traction force $F_x$ and steering angle $\delta$ via tire model. The last two will be used to slack the friction cone constraints.
#
# The reason of introducing auxiliary variables is that more variabel sometimes results in less nonlinearity.
#
# Thus the NMPC problem will take the form:
#
# $$
#     \begin{aligned}
#     J_0^{*}(s_{init}) = \min_{s_k, u_k, z_k} & \ p(s_N) + \sum_{k=0}^{N-1} q(s_k, u_k, z_k)\\
#     \text{s.t. }
#                 %  & x_{k+1} =  \ k = 0, \dots, N-1, \\
#                 & s_{k+1} = f(s_k, u_k, z_k), k = 0, \dots, N-1, \\
#                 & 0=TireModel(s_k, u_k, z_k), \\
#                 & FrictionCone(s_k, z_k, u_k) \le 0, \\
#                 & OtherConstraints(s_k, z_k, u_k) \le 0, \\
#                 & u_{\min} \le u_k \le u_{\max}, \\
#                 & x_0 = x_{init}.
#     \end{aligned}
# $$

# %% [markdown]
# ## Detail of constraints
# ### Friction cone constraints:
#
# We introduce the slacked friction cone constraints:
#
# $$ F_{y_f, k}^2 + F_{x_f, k}^2 \le (\mu_f F_{z_f, k})^2 + z_{\mu_f}^2  $$
# $$ F_{y_r, k}^2 + F_{x_r, k}^2 \le (\mu_r F_{z_r, k})^2 + z_{\mu_r}^2  $$
#
#
# ### Obstacle avoidance:
#
# The car should avoid colliding with the sphere obstacle:
#
# $$ \left(\frac{x_k - 500}{10}\right)^2 + \left(\frac{y_k}{10}\right)^2 \ge 1  $$
#
# ### Input constraints:
#
# Steering angle can not exceed the maximal value:
# $$-\delta_{\max} \le \delta_k \le \delta_{\max}$$
#
# Traction force can not exceed the engine power constraints:
# $$ F_x \le \frac{P_{eng}}{U_x }$$
#
# ### Positive longitudinal speed
#
# We do not want to drive in reverse:
#
# $$ U_x \ge 2 $$

# %% [markdown]
# ## Cost function design
#
# ### Stay close to the "lane":
#
# Design a cost function to encourage the car to approach the lane: $y_k \rightarrow 0$.
#
# ### Stabilize the yaw angle:
#
# Design a cost function to encourage the car to maintain zero yaw angle: $\phi_k \rightarrow 0$.
#
# ### Drive fast / far:
#
# Design a cost function to encourage the car to drive as fast as possible, i.e. $U_x \rightarrow +\infty$ and $x \rightarrow +\infty$
#
# ### Avoid tire saturation:
#
# Design a cost function to encourage the slip angle be smaller than the modified slip angle:
#
# $$
# J_\alpha=W_\alpha \sum_{k=1}^N \begin{cases}\left(\left| \alpha_{k}\right|- \alpha_{k}^{\bmod }\right)^2, & \text { if }\left| \alpha_{k}\right| \geq \alpha_{k}^{\bmod } \\ 0, & \text { otherwise. }\end{cases}
# $$
#
# where $W_{\alpha}$ is a large weight. Add this cost using the **ca.if_else()** function. The $\alpha^{mod}$ is the modified slide slipping angle.
#
# ### Penalize the slack variable of friction cone constraints:
#
# Add a large weight to $z_{\mu_{f}}^2$ and $z_{\mu_{r}}^2$.

# %% [markdown]
# ## Submission
#
# You are required to implement the controller on $5$ known test cases.
#
# ### Controller:
#
# Please complete the function **nmpc_controller()** and submit the file.
#
# ### Initial guess for warm-start:
#
# Please submit the initial guess of the your NMPC solver for warm-start, i.e. the **\*.mat** files. You are supposed to compute it offline for as long as you wish untill convergence.
#
# We have provided examples of initial guesses for the five test cases. However, you need to compute these **\*.mat** file based on your own controller.
#
# ### Evaluation:
#
# We will evaluate the closed-loop trajectory based on the distance traveled in the $x$ direction and the deviation in $y$ direction.
#
# Larger distance in $x$ direction and less deviation from $y$ will lead to higher score.
#
# Collision with obstacle will result in large penalty.

# %% [markdown]
# ## Remark
#
# In runtime, the NMPC is not required to converge to optimal value. We set the **ipopt.max_iter** to $100$ make sure the simulation time is reasonable. The GSI took less than $90$ secs to complete the simulation for one test cases.
#
# As long as the NMPC is **feasible**, suboptimal solution can still stabilize the system as long as the suboptimality is not too big.

# %% [markdown]
# ## Code start

# %% [markdown]
# ### Get an NMPC controller

# %%
## build a controller 
prob, N_mpc, n_x, n_g, n_p, lb_var, ub_var, lb_cons, ub_cons = nmpc_controller(None)

# %% [markdown]
# ### Compoute the solution for initial condition
#
# You are supposed to compute the solution of your NMPC controller for each initial conditions and save it as a **case_#.mat** file.
#
# Only uncomment one line each time and continue.
#
# Once you obtained the initial guess for one cases, you can resuse it for initial guess of other cases.

# %%
## random initialization
x0_nlp    = np.random.randn(n_x, 1) * 0.025 # 
lamx0_nlp = np.random.randn(n_x, 1) * 0.025 # 
lamg0_nlp = np.random.randn(n_g, 1) * 0.025 # 

## initialization using known solution
# initial_guess = scipy.io.loadmat("case_3.mat") # Once you have a solution, you can use it as initial guess for other cases
# x0_nlp = initial_guess["x0_nlp"]
# lamx0_nlp = initial_guess["lamx0_nlp"]
# lamg0_nlp = initial_guess["lamg0_nlp"]

## uncomment one line each time 
# init = np.array([50, 0.0, 0.0, 0,  0, 0]); file_name = "case_1.mat" 
# init = np.array([3, 0.0, 0.0, 0,  0, 0]); file_name = "case_2.mat"
# init = np.array([30, 0.0, 0., 0,  30, 0]); file_name = "case_3.mat"
# init = np.array([30, 0.0, 0.0, 0,  50, 0.3]); file_name = "case_4.mat"
init = np.array([3, 0.0, 0.0, 0, 30, 1.57]); file_name = "case_5.mat"

## run sufficiently long time to ensure the solver converges to opitmal value
opts = {'ipopt.max_iter':6000}

solver = ca.nlpsol('solver', 'ipopt', prob , opts)
sol = solver(x0=x0_nlp, lam_x0=lamx0_nlp, lam_g0=lamg0_nlp,
                     lbx=lb_var, ubx=ub_var, lbg=lb_cons, ubg=ub_cons, p=init)
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:     1356
# Number of nonzeros in inequality constraint Jacobian.:      480
# Number of nonzeros in Lagrangian Hessian.............:      693
#
# Total number of variables............................:      366
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      366
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      246
# Total number of inequality constraints...............:      150
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:      150
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.8079717e+10 2.98e+13 1.41e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.8076079e+10 2.60e+13 1.72e+07  -1.0 4.79e+06    -  3.67e-05 3.07e-05h  1
#    2  1.8075921e+10 2.60e+13 2.74e+07  -1.0 2.34e+06   2.0 3.97e-08 2.10e-06h  1
#    3r 1.8075921e+10 2.60e+13 9.99e+02   5.4 0.00e+00   1.5 0.00e+00 1.05e-08R  2
#    4r 1.7540538e+10 2.59e+13 9.99e+02   5.4 2.61e+08    -  8.94e-05 2.58e-06f  1
#    5r 1.1264258e+10 1.16e+13 1.14e+12   5.4 5.41e+03   2.0 1.72e-01 1.74e-03f  1
#    6r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  13.8 1.98e-02 2.07e-02h  1
# WARNING: Problem in step computation; switching to emergency mode.
#    7r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#    8r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#    9r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   11r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   12r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   13r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   14r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   15r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   16r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   17r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   18r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   19r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   21r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   22r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   23r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   24r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   25r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   26r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   27r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   28r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   29r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   31r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   32r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   33r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   34r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   35r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   36r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   37r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   38r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   39r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   41r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   42r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   43r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   44r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   45r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   46r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   47r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   48r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   49r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   51r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   52r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   53r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   54r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   55r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   56r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   57r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   58r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   59r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   61r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   62r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   63r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   64r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   65r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   66r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   67r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   68r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   69r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   71r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   72r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   73r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   74r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   75r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   76r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   77r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   78r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   79r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   81r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   82r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   83r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   84r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   85r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   86r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   87r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   88r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   89r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   91r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   92r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   93r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   94r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   95r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   96r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   97r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   98r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#   99r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  101r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  102r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  103r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  104r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  105r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  106r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  107r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  108r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  109r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  111r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  112r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  113r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  114r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  115r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  116r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  117r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  118r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  119r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  121r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  122r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  123r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  124r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  125r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  126r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  127r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  128r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  129r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  131r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  132r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  133r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  134r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  135r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  136r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  137r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  138r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  139r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  141r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  142r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  143r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  144r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  145r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  146r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  147r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  148r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  149r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  151r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  152r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  153r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  154r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  155r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  156r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  157r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  158r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  159r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  161r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  162r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  163r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  164r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  165r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  166r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  167r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  168r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  169r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  171r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  172r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  173r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  174r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  175r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  176r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  177r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  178r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  179r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  181r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  182r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  183r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  184r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  185r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  186r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  187r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  188r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  189r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  191r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  192r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  193r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  194r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  195r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  196r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  197r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  198r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  199r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  201r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  202r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  203r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  204r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  205r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  206r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  207r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  208r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  209r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  211r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  212r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  213r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  214r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  215r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  216r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  217r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  218r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  219r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  221r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  222r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  223r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  224r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  225r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  226r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  227r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  228r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  229r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  231r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  232r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  233r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  234r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  235r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  236r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  237r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  238r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  239r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  241r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  242r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  243r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  244r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  245r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  246r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  247r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  248r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  249r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  251r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  252r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  253r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  254r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  255r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  256r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  257r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  258r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  259r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  261r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  262r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  263r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  264r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  265r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  266r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  267r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  268r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  269r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  271r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  272r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  273r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  274r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  275r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  276r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  277r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  278r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  279r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  281r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  282r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  283r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  284r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  285r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  286r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  287r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  288r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  289r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  291r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  292r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  293r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  294r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  295r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  296r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  297r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  298r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  299r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  301r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  302r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
#  303r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# ...
# WARNING: Problem in step computation; switching to emergency mode.
# 3016r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3017r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3018r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3019r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3020r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3021r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3022r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3023r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3024r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3025r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3026r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3027r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3028r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3029r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3030r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3031r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3032r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3033r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3034r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3035r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3036r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3037r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3038r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3039r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3040r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3041r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3042r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3043r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3044r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3045r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3046r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3047r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3048r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3049r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3050r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3051r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3052r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3053r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3054r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3055r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3056r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3057r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3058r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3059r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3060r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3061r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3062r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3063r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3064r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3065r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3066r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3067r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3068r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3069r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3070r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3071r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3072r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3073r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3074r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3075r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3076r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3077r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3078r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3079r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3080r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3081r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3082r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3083r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3084r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3085r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3086r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3087r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3088r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3089r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3090r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3091r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3092r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3093r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3094r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3095r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3096r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3097r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3098r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3099r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3100r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3101r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3102r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3103r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3104r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3105r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3106r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3107r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3108r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3109r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# 3110r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3111r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3112r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3113r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3114r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3115r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3116r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.
# 3117r 1.1414074e+10 1.13e+13 1.32e+20   5.4 2.43e+02  20.0 0.00e+00 0.00e+00R  1
# WARNING: Problem in step computation; switching to emergency mode.

# %% [markdown]
# ### Compare the solution after warm-start
#
# You can find the solver is fast if the initial guess is properly provided.
#
# Sabve the initial guess for submission and your simulations.

# %%
## you will see how fast the solver is if it is initialized properly
x0_nlp    = sol["x"].full()
lamx0_nlp = sol["lam_x"].full()
lamg0_nlp = sol["lam_g"].full() # np.zeros((n_g, 1))
sol = solver(x0=x0_nlp, lam_x0=lamx0_nlp, lam_g0=lamg0_nlp,
                     lbx=lb_var, ubx=ub_var, lbg=lb_cons, ubg=ub_cons, p=init)

## save the initial guess if you are satisfied
scipy.io.savemat(file_name, {'x0_nlp': x0_nlp, "lamx0_nlp": lamx0_nlp, "lamg0_nlp": lamg0_nlp})

# %%
# You can plot the solution here to see if it is reasonable. 

u = sol["x"].full()[0:N_mpc * 2]
x = sol["x"].full()[N_mpc * 2:N_mpc * 2 + (N_mpc + 1) * 6]

# %% [markdown]
# ### Retrive the initial solutions for simulation.
#
# If you already have the initial solutions, you can start from this block to retrive them.

# %%
## test the controller with different inirial states and guesses
## uncomment one line each time and test the controller
# init = np.array([50, 0.0, 0.0, 0,  0, 0]); file_name = "case_1.mat"
# init = np.array([3, 0.0, 0.0, 0,  0, 0]); file_name = "case_2.mat"
# init = np.array([30, 0.0, 0., 0,  30, 0]); file_name = "case_3.mat"
# init = np.array([30, 0.0, 0.0, 0,  50, 0.3]); file_name = "case_4.mat"
init = np.array([3, 0.0, 0.0, 0, 30, 1.57]); file_name = "case_5.mat"

initial_guess = scipy.io.loadmat(file_name)
x0_nlp = initial_guess["x0_nlp"]
lamx0_nlp = initial_guess["lamx0_nlp"]
lamg0_nlp = initial_guess["lamg0_nlp"]

# %% [markdown]
# ### Simulation start!
#
# We will simulate the vehicle for 30 secs.
#
# As we are using fixed-step RK simulator and limits the maximal iteration for IPOPT, the simulation time is controllable.

# %%
## build a car simulator
## The car will be driving for 30 secs
## The control rate is 10 HZ.
T_sim  = 30
dt_ctrl = 0.1; rk_interval = 10
N_sim = int(np.ceil(T_sim / dt_ctrl))
integrator, car_dynamics = GetCarModel(None, ts = np.linspace(0, dt_ctrl, rk_interval), ode = "rk")
sim_time = np.linspace(0, T_sim, N_sim * (rk_interval - 1) + 1)

# %%
y0 = np.reshape(init, (6, 1))
x_log, u_log, tire_force_log = SimVehicle(y0, nmpc_controller, integrator, car_dynamics, N_sim, True, x0_nlp, lamx0_nlp, lamg0_nlp)

# %% [markdown]
# ### Trajectory
#
# You are supposed to avoid the obstacle, while trying to keep $y = 0$ and reach larger $x$.

# %%
print("Distance traveled in x direction:")
print(np.max(x_log[3, :]))

print("std. dev in y direction:")
print(np.std(x_log[4, :]))

# %%
# trajectory in the world frame

plt.figure(figsize=(20, 10))
plt.plot(x_log[3, 0], x_log[4, 0], "r.", markersize = 20)
plt.plot(x_log[3, :], x_log[4, :])
plt.axis("scaled")

plt.title("Trajectory")
plt.xlabel("x")
plt.ylabel("y")

theta = np.linspace(0, np.pi * 2, 100)
plt.plot(np.sin(theta) * 10 + 500, np.cos(theta) * 10)
plt.ylim([np.min(x_log[4, :]) -10, np.max(x_log[4, :]) + 10])

plt.grid()
plt.show()

plt.figure(figsize=(20, 3))
plt.plot(sim_time, x_log[5])
plt.xlim([0, T_sim])
plt.title("Yaw Angle")
plt.xlabel("Time(s)")
plt.ylabel("rad")
plt.grid()
plt.show()

# %% [markdown]
# ### Velocity

# %%
plt.figure(figsize=(20, 5))
plt.plot(sim_time, x_log[0, :], label = "$U_x$" )
plt.xlim([0, T_sim])

plt.title("Longitudinal Velocity")
plt.xlabel("Time(s)")
plt.ylabel("m/s")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(20, 5))
plt.plot(sim_time, x_log[1, :], label = "$U_y$" )
plt.plot(sim_time, x_log[2, :], label = "$\dot{r}$" )
plt.xlim([0, T_sim])

plt.title("Lateral Velocity / Yaw rate")
plt.xlabel("Time(s)")
plt.ylabel("m/s (rad/s)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Control input
#
# The traction force will decrease due to the engine power limits when the velocity is large.

# %%
rk_interval = 10
plt.figure(figsize=(20, 5))
plt.plot(sim_time[1::rk_interval-1], u_log[1, 1:])
plt.xlim([0, T_sim])
plt.title("Steering Angle")
plt.xlabel("Time(s)")
plt.ylabel("rad")
plt.grid()
plt.show()

plt.figure(figsize=(20, 5))
plt.plot(sim_time[1::rk_interval-1], u_log[0, 1:] / 1000)
plt.xlim([0, T_sim])
plt.title("Traction Force")
plt.xlabel("Time(s)")
plt.ylabel("kN")
plt.grid()
plt.show()

# %% [markdown]
# ### Tire force
#
# For successful trial, the tire force should distributed at the boundary of the friction cone for larger acceleration and braking.

# %%
rk_interval = 2
plt.figure(figsize=(20, 4))
plt.plot(sim_time[1::rk_interval-1], tire_force_log[0:3, 1:].T / 1000)
plt.title("Front Tire Forces")
plt.legend(["$F_x$", "$F_y$", "$F_z$"])
plt.ylabel("Force (kN)")
plt.xlabel("Time (s)")
plt.xlim([0, T_sim])
plt.grid()
plt.show()

plt.figure(figsize=(20, 4))
plt.plot(sim_time[1::rk_interval-1], tire_force_log[4:7, 1:].T / 1000)
plt.title("Rear Tire Forces")
plt.legend(["$F_x$", "$F_y$", "$F_z$"])
plt.ylabel("Force (kN)")
plt.xlabel("Time (s)")
plt.xlim([0, T_sim])
plt.grid()
plt.show()

inter = 1
Fx_f = tire_force_log[0, 1::inter].T / tire_force_log[2, 1::inter].T
Fy_f = tire_force_log[1, 1::inter].T / tire_force_log[2, 1::inter].T

Fx_r = tire_force_log[4, 1::inter].T / tire_force_log[6, 1::inter].T
Fy_r = tire_force_log[5, 1::inter].T / tire_force_log[6, 1::inter].T

plt.figure(figsize=(20, 4))
plt.plot(sim_time[1::rk_interval-1], 1 - (Fx_f**2 + Fy_f**2) / param["mu_f"]**2 , label = "Front tire" )
plt.plot(sim_time[1::rk_interval-1], 1 - (Fx_r**2 + Fy_r**2) / param["mu_r"]**2 , label = "Rear tire" )
plt.title("Normalized Friction Cone")
plt.xlabel("Time (s)")
plt.xlim([0, T_sim])
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(15, 15))
plt.plot(Fx_f, Fy_f , "-o",  label = "Front tire" )
plt.plot(Fx_r, Fy_r , "-o", label = "Rear tire" )

plt.plot(Fx_f[0], Fy_f[0] , "g*")
plt.plot(Fx_r[0], Fy_r[0] , "g*")

plt.plot(np.cos(np.linspace(0, np.pi * 2, 100)) * param["mu_f"], np.sin(np.linspace(0, np.pi * 2, 100)) * param["mu_f"], "k--", label = "Front tire limits")
plt.plot(np.cos(np.linspace(0, np.pi * 2, 100)) * param["mu_r"], np.sin(np.linspace(0, np.pi * 2, 100)) * param["mu_r"], "b--", label = "Rear tire limits")

plt.title("Normalized Friction Cone")
plt.ylabel("$F_y$")
plt.xlabel("$F_x$")
plt.legend()
plt.grid()
plt.show()
